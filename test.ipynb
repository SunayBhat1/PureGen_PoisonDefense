# %%
from diffusers import UNet2DModel
model_id = "google/ddpm-cifar10-32"
gen = UNet2DModel.from_pretrained(model_id)
# gen = gen.to(device)
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/research/lib/python3.8/site-packages/diffusers/models/modeling_utils.py:108, in load_state_dict(checkpoint_file, variant)
#     107 if file_extension == SAFETENSORS_FILE_EXTENSION:
# --> 108     return safetensors.torch.load_file(checkpoint_file, device="cpu")
#     109 else:
#
# AttributeError: module 'safetensors' has no attribute 'torch'
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/miniconda3/envs/research/lib/python3.8/site-packages/diffusers/models/modeling_utils.py:114, in load_state_dict(checkpoint_file, variant)
#     113 with open(checkpoint_file) as f:
# --> 114     if f.read().startswith("version"):
#     115         raise OSError(
#     116             "You seem to have cloned a repository without having git-lfs installed. Please install "
#     117             "git-lfs and run `git lfs install` followed by `git lfs pull` in the folder "
#     118             "you cloned."
#     119         )
#
# File ~/miniconda3/envs/research/lib/python3.8/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     321 data = self.buffer + input
# --> 322 (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323 # keep undecoded input until the next call
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x88 in position 1: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 from diffusers import UNet2DModel
#       2 model_id = "google/ddpm-cifar10-32"
# ----> 3 gen = UNet2DModel.from_pretrained(model_id)
#
# File ~/miniconda3/envs/research/lib/python3.8/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/research/lib/python3.8/site-packages/diffusers/models/modeling_utils.py:740, in ModelMixin.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     737 else:
#     738     model = cls.from_config(config, **unused_kwargs)
# --> 740     state_dict = load_state_dict(model_file, variant=variant)
#     741     model._convert_deprecated_attention_blocks(state_dict)
#     743     model, missing_keys, unexpected_keys, mismatched_keys, error_msgs = cls._load_pretrained_model(
#     744         model,
#     745         state_dict,
#    (...)
#     748         ignore_mismatched_sizes=ignore_mismatched_sizes,
#     749     )
#
# File ~/miniconda3/envs/research/lib/python3.8/site-packages/diffusers/models/modeling_utils.py:126, in load_state_dict(checkpoint_file, variant)
#     121             raise ValueError(
#     122                 f"Unable to locate the file {checkpoint_file} which is necessary to load this pretrained "
#     123                 "model. Make sure you have saved the model properly."
#     124             ) from e
#     125 except (UnicodeDecodeError, ValueError):
# --> 126     raise OSError(
#     127         f"Unable to load weights from checkpoint file for '{checkpoint_file}' "
#     128         f"at '{checkpoint_file}'. "
#     129         "If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True."
#     130     )
#
# OSError: Unable to load weights from checkpoint file for '/Users/sunaybhat/.cache/huggingface/hub/models--google--ddpm-cifar10-32/snapshots/267b167dc01f0e4e61923ea244e8b988f84deb80/diffusion_pytorch_model.safetensors' at '/Users/sunaybhat/.cache/huggingface/hub/models--google--ddpm-cifar10-32/snapshots/267b167dc01f0e4e61923ea244e8b988f84deb80/diffusion_pytorch_model.safetensors'. If you tried to load a PyTorch model from a TF 2.0 checkpoint, please set from_tf=True.
